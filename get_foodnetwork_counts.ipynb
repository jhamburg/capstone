# %%
import pandas as pd
import numpy as np

# %%
datFile = 'data/foodNetwork_count.json'
tmp1 = pd.read_json(datFile)

# %%
print(tmp.drop_duplicates().numLinks.sum())
print(tmp1.drop_duplicates().numLinks.sum())
# Out:
# 724634
# 612124

# %%
tmp.sort_values(by = 'numLinks', ascending=False)
# Out:
#      numLinks                           topic
# 238    107992     Portobello Mushroom Recipes
# 43      31337               Vegetable Recipes
# 342     20305               Main Dish Recipes
# 465     19907                   Fruit Recipes
# 336     16022                    Meat Recipes
# 515     15658                    Easy Recipes
# 527     14089                 Dessert Recipes
# 620     12069                  Cheese Recipes
# 744     12022                        American
# 141      9352               Side Dish Recipes
# 401      9082                 Holiday Recipes
# 529      8790                   Dairy Recipes
# 742      8249              Appetizer Recipes
# 523      8088                  Dinner Recipes
# 230      8061                 Poultry Recipes
# 345      7354                   Lunch Recipes
# 460      6888           Fruit Dessert Recipes
# 63       6489                  Tomato Recipes
# 723      6449                  Baking Recipes
# 612      6140                 Chicken Recipes
# 426      5672                Grilling Recipes
# 306      5572                     Nut Recipes
# 391      5472           Italian Pizza Recipes
# 590      5469               Chocolate Recipes
# 500      5318          Easy Main Dish Recipes
# 149      5093               Shellfish Recipes
# 175      4707                   Salad Recipes
# 394      4625                 Italian Recipes
# 206      4540             Recipes for Parties
# 415      4417                 Healthy Recipes
# ..        ...                             ...
# 39         13                      Venezuelan
# 176        13         Salisbury Steak Recipes
# 50         13                         Turkish
# 366        13      Lemon Meringue Pie Recipes
# 680        13        Boston Cream Pie Recipes
# 15         13           Apple Strudel Recipes
# 413        13        Hard Boiled Eggs Recipes
# 373        13                Lebanese Recipes
# 268        13            Pepper Steak Recipes
# 699        12         Beef Wellington Recipes
# 355        12         Lobster Ravioli Recipes
# 91         12                Sturgeon Recipes
# 27         12     White Chicken Chili Recipes
# 495        11                     Eel Recipes
# 21         11                Yule Log Recipes
# 117        11  Sweet And Sour Chicken Recipes
# 183        11                    Rosh Hashana
# 178        10               Rye Flour Recipes
# 274        10      Peanut Butter Ball Recipes
# 276         9          Peanut Brittle Recipes
# 721         9           Baked Tilapia Recipes
# 172         8           Salmon Mousse Recipes
# 115         8             Sponge Cake Recipes
# 724         8         Baked Spaghetti Recipes
# 614         8               Chess Pie Recipes
# 95          6           Stuffed Shell Recipes
# 202         6           Rhubarb Crisp Recipes
# 255         6       Pigs In A Blanket Recipes
# 356         4          Lobster Bisque Recipes
# 81          1     Sweet and Sour Pork Recipes
#
# [754 rows x 2 columns]
